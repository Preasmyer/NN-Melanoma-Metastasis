# %% [markdown]
# # Method of transforming whole image to png

# %%
import openslide
from tqdm import tqdm
from PIL import Image
import numpy as np
import os

def resize_ndpi_image(ndpi_path, output_path, target_size=(1024, 1024)):
    slide = openslide.OpenSlide(ndpi_path)
    
    # Choose a level with reasonable resolution
    level = slide.get_best_level_for_downsample(32)
    thumbnail = slide.read_region((0, 0), level, slide.level_dimensions[level])
    
    # Convert to RGB and resize
    thumbnail = thumbnail.convert("RGB")
    resized = thumbnail.resize(target_size, Image.Resampling.LANCZOS)

    
    resized.save(output_path)

# %%
# input_dir = "/Volumes/Maxtor/CONTINUACION Basurto y Cruces"  # 1
# input_dir = "/Volumes/TOSHIBA EXT/Melanomas IHC" # 2
input_dir = "/Volumes/EXTERNAL_USB/elkartek-CRUCES"  # 3

# output_dir = "/Users/cameronpreasmyer/Desktop/Images/Basurto and Cruces" # 1
# output_dir = "/Users/cameronpreasmyer/Desktop/Images/Melanomas IHC" # 2 
output_dir = "/Users/cameronpreasmyer/Desktop/Images/Elkartek" # 3
for filename in os.listdir(input_dir):
    if filename.endswith(".ndpi"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename.replace(".ndpi", ".png"))
        resize_ndpi_image(input_path, output_path)

# %% [markdown]
# # Sorting Algo

# %%
import os
import shutil

keywords = ["PIR", "PBP", "MITF", "HE", "ANX", "BRAF", "BCL2", "BCL3"]
#source_folder = "/Users/cameronpreasmyer/Desktop/Images/Basurto and Cruces"
#source_folder = "/Users/cameronpreasmyer/Desktop/Images/Melanomas IHC"
source_folder = "/Users/cameronpreasmyer/Desktop/Images/Elkartek"
destination_root = "/Users/cameronpreasmyer/Desktop/Images2/ROOT"


for filename in os.listdir(source_folder):
    upper_name = filename.upper()
    for keyword in keywords:
        if keyword in upper_name:
            keyword_folder = os.path.join(destination_root, keyword)
            os.makedirs(keyword_folder, exist_ok=True)
            src_path = os.path.join(source_folder, filename)
            dst_path = os.path.join(keyword_folder, filename)
            shutil.move(src_path, dst_path)
            print(f"Moved {filename} to {keyword_folder}")
            break  # Avoid moving the same file to multiple folders
# Out:
# Moved EL-C249-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C077Pch-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C118-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C048-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C239-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C145NCA-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C239-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C126ND-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C093-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C025-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C077Pch-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C077Pch-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C035-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C032-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C248-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C249-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C249-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C116NID-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C248-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C077Pch-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C037N-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C126ND-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C118-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C214-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C252-BCL3 - 2018-07-12 14.43.02.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C116NID-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C230-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C242-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C242-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C024-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C025-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C243-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C229-ANX - 2018-05-23 17.11.13.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C126ND-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C030-PIR2 - 2018-07-11 21.10.54.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C254 Bx-PBP - 2018-05-23 19.05.38.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C240-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C250-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C225-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C126ND-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C242-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C230-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C035-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C037N-PBPbis.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C225R-BCL2 - 2018-05-23 16.20.11.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C096P-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C240-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C243-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C025-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C024-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C242-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C170-MITF - 2018-05-23 15.22.49.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C232R-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C170-PIR - 2018-05-23 15.00.58.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C039-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C098NID-PIR2 - 2018-07-12 13.07.34.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C054NID-PIR2 - 2018-07-11 21.14.37.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-
PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C255-MITF - 2018-05-23 21.02.21.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C138-PIR2 - 2018-07-12 13.36.46.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C022 M-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C198 ND-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C030-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C059a-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C176-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C176-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C098NID-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C096P-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C037N-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C026-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C240-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C232R-PIR2 - 2018-07-12 14.07.51.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C232R-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C164-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C041-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C096P-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C222 Mx-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C176-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C096P-PIR2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C023-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C225 MN-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C250-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C036-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C037N-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C031-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C031-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C225R-PBP - 2018-05-23 15.59.09.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C021-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C021-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C031-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C040-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C037N-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C176-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C240-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C026-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C225 MN-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C023-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C041-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C229-BCL2 - 2018-05-23 17.04.51.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C243-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C232R-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C126ND-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C225 MN-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C229-PBP - 2018-05-23 16.46.29.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C028-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C225 MN-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C040-MITF - 2018-07-12 15.01.29.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C037 M-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C048-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C037 M-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C037 M-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C093-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C028-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C230-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C039-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C021-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C054 NID-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C035-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C176-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C048-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C252-BCL3 - 2018-05-24 10.07.00.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C046-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C170-BCL3 - 2018-05-23 15.15.45.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C054 NID-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C225 MN-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C138-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C041-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C023-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C054 NID-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C037N-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C254 Bx-PIR - 2018-05-23 18.50.22.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C059a-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C030-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C031-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C021-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C021-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C031-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C023-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C041-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C230-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C198 ND-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C096P-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C225R-PIR - 2018-05-23 15.51.51.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C222 Mx-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C222 Mx-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C214-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C093-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C028-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C048-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C116NID-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C037 M-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C048-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C225R-ANX - 2018-05-23 16.27.12.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C093-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C093-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C037 M-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C232R-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C255-HE - 2018-05-23 20.20.15.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C059a-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C176-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C098NID-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C250-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C036-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C240 Mx-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C041-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C255-ANX - 2018-05-23 21.23.08.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C222 Mx-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C041-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C225-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C229-MITF - 2018-05-23 16.57.42.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C036-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C250-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C238-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C039-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C245-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C098NID-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C077-PIR2 - 2018-07-11 21.16.53.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C196-PIR2 - 2018-07-12 13.49.27.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C176-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C245-PIR.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C026-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C249-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C240-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C225-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C232R-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C037N-BCL3bis.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C037 M-BCL2.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL2
# Moved EL-C129-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C116NID-PIR2 - 2018-07-12 13.09.28.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PIR
# Moved EL-C225 MN-MITF.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/MITF
# Moved EL-C025-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C225 MN-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C254 Bx-BCL3 - 2018-05-23 19.20.51.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C046-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C240 Mx-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C022 M-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C040-BCL3 - 2018-07-12 14.55.02.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C059a-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C032-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C138-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C032-ANX.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/ANX
# Moved EL-C138-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C037 M-BCL3.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/BCL3
# Moved EL-C059a-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP
# Moved EL-C162-HE.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/HE
# Moved EL-C022 M-PBP.png to /Users/cameronpreasmyer/Desktop/Images2/ROOT/PBP

# %% [markdown]
# # Method of transforming whole image to Tiles

# %%
def is_informative(tile, threshold=0.92):
    '''
    Returns True if the tile is informative, False otherwise.
    '''
    arr = np.array(tile)
    gray = np.mean(arr, axis=-1)
    white_pixels = np.sum(gray > 224)
    total_pixels = gray.size
    return (white_pixels / total_pixels) < threshold

# %%
def extract_tiles(slide_path, output_dir, tile_size=(512, 512), stride=512):
    slide = openslide.OpenSlide(slide_path)
    width, height = slide.dimensions
    os.makedirs(output_dir, exist_ok=True)

    # Calculate total number of tiles
    total_tiles = ((height - tile_size[1]) // stride + 1) * ((width - tile_size[0]) // stride + 1)
    count = 0

    with tqdm(total=total_tiles, desc="Extracting tiles") as pbar:
        for y in range(0, height, stride):
            for x in range(0, width, stride):
                if x + tile_size[0] <= width and y + tile_size[1] <= height:
                    tile = slide.read_region((x, y), 0, tile_size).convert("RGB")
                    if is_informative(tile):
                        tile.save(os.path.join(output_dir, f"tile_{count}.png"))
                        count += 1
                    pbar.update(1)

# %%
# Testing levels of informative-ness to tweak above threshold and gray value

is_informative(Image.open("/Users/cameronpreasmyer/Desktop/outputtest/tiles/tile_69.png"))
# Out:
# np.True_

# %%
input_ndpi = "/Users/cameronpreasmyer/Desktop/Inputtest/EL-C021-ANX.ndpi"
output_tiles = "/Users/cameronpreasmyer/Desktop/outputtest/tiles"

extract_tiles(input_ndpi, output_tiles, tile_size=(512, 512), stride=512)
# Out:
# Extracting tiles:  17%|█▋        | 4269/25740 [03:30<17:38, 20.29it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/ImageFile.py:554, in _save(im, fp, tile, bufsize)
#     553 try:
# --> 554     fh = fp.fileno()
#     555     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[145], line 4
#       1 input_ndpi = "/Users/cameronpreasmyer/Desktop/Inputtest/EL-C021-ANX.ndpi"
#       2 output_tiles = "/Users/cameronpreasmyer/Desktop/outputtest/tiles"
# ----> 4 extract_tiles(input_ndpi, output_tiles, tile_size=(512, 512), stride=512)
#
# Cell In[144], line 16, in extract_tiles(slide_path, output_dir, tile_size, stride)
#      14 tile = slide.read_region((x, y), 0, tile_size).convert("RGB")
#      15 if is_informative(tile):
# ---> 16     tile.save(os.path.join(output_dir, f"tile_{count}.png"))
#      17     count += 1
#      18 pbar.update(1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2596, in Image.save(self, fp, format, **params)
#    2593     fp = cast(IO[bytes], fp)
#    2595 try:
# -> 2596     save_handler(self, fp, filename)
#    2597 except Exception:
#    2598     if open_fp:
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1488, in _save(im, fp, filename, chunk, save_all)
#    1484     single_im = _write_multiple_frames(
#    1485         im, fp, chunk, mode, rawmode, default_image, append_images
#    1486     )
#    1487 if single_im:
# -> 1488     ImageFile._save(
#    1489         single_im,
#    1490         cast(IO[bytes], _idat(fp, chunk)),
#    1491         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1492     )
#    1494 if info:
#    1495     for info_chunk in info.chunks:
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/ImageFile.py:558, in _save(im, fp, tile, bufsize)
#     556     _encode_tile(im, fp, tile, bufsize, fh)
#     557 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 558     _encode_tile(im, fp, tile, bufsize, None, exc)
#     559 if hasattr(fp, "flush"):
#     560     fp.flush()
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/ImageFile.py:584, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     581 if exc:
#     582     # compress to Python file-compatible object
#     583     while True:
# --> 584         errcode, data = encoder.encode(bufsize)[1:]
#     585         fp.write(data)
#     586         if errcode:
#
# KeyboardInterrupt:
